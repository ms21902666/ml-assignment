# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plott

# %%
import warnings

# %%
import seaborn as sns

# %%
warnings.filterwarnings('ignore')

# %%
avocado = pd.read_csv("avocado.csv")
avocado
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1               1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2               2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3               3   12/6/2015          1.08      78992.15  1132.00   71976.41
# 4               4  11/29/2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7    2/4/2018          1.63      17074.83  2046.96    1529.20
# 18245           8   1/28/2018          1.71      13888.04  1191.70    3431.50
# 18246           9   1/21/2018          1.87      13766.76  1191.92    2452.79
# 18247          10   1/14/2018          1.93      16205.22  1527.63    2981.04
# 18248          11    1/7/2018          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1           1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2           2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3           3   12/6/2015          1.08      78992.15  1132.00   71976.41
# 4           4  11/29/2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
avocado.drop('Unnamed: 0',inplace=True,axis=1)

# %%
avocado.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  12/27/2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  12/20/2015          1.35      54876.98   674.28   44638.81   58.33
# 2  12/13/2015          0.93     118220.22   794.70  109149.67  130.50
# 3   12/6/2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  11/29/2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
avocado.shape
# Out:
# (18249, 13)

# %%
avocado.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
avocado.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
sns.heatmap(avocado.isnull())
# Out:
# <Axes: >

# %%
avocado.groupby('year')['type'].value_counts()
# Out:
# year  type
# 2015  conventional    2808
#       organic         2807
# 2016  conventional    2808
#       organic         2808
# 2017  conventional    2862
#       organic         2860
# 2018  conventional     648
#       organic          648
# Name: count, dtype: int64

# %%
avocado.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
sns.pairplot(avocado, x_vars=['4770'],
y_vars='Total Volume', size=5, aspect=1, kind='scatter')
plott.show()

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.svm import SVC

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
sns.heatmap(avocado.corr(), cmap="YlGnBu", annot = True)
plott.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 sns.heatmap(avocado.corr(), cmap="YlGnBu", annot = True)
#       2 plott.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
from sklearn.externals import joblib
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 from sklearn.externals import joblib
#
# ImportError: cannot import name 'joblib' from 'sklearn.externals' (C:\Users\HP\anaconda3\Lib\site-packages\sklearn\externals\__init__.py)

# %%
avocado.drop('Date',inplace=True,axis=1)

# %%
avocado.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5677.40      133.76          0.0  conventional  2015  Albany
# 4     5986.26      197.69          0.0  conventional  2015  Albany

# %%
avocado.drop('type',inplace=True,axis=1)

# %%
avocado.drop('region',inplace=True,axis=1)

# %%
avocado_cor=avocado.corr()

# %%
plott.figure(figsize=(30,25))

# %%
sns.heatmap(avocado_cor,annot=True)
# Out:
# <Axes: >

# %%
X_ind = avocado['4770']
y_dep = avocado['Total Volume']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_ind, y_dep, train_size = 0.7,
test_size = 0.3, random_state = 100)

# %%
import statsmodels.api as stats_mod

# %%
X_train_sm = stats_mod.add_constant(X_train)

# %%
lin_reg = stats_mod.OLS(y_train, X_train_sm).fit()
lin_reg.params
# Out:
# const    204303.581637
# 4770         27.913119
# dtype: float64

# %%
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Total Volume   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.755
# Method:                 Least Squares   F-statistic:                 3.947e+04
# Date:                Sun, 22 Oct 2023   Prob (F-statistic):               0.00
# Time:                        22:53:26   Log-Likelihood:            -2.0147e+05
# No. Observations:               12774   AIC:                         4.029e+05
# Df Residuals:                   12772   BIC:                         4.030e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.043e+05   1.55e+04     13.188      0.000    1.74e+05    2.35e+05
# ...

# %%
plott.scatter(X_train, y_train)
plott.plot(X_train, 2.043e+05 + 27.9131*X_train, 'r')
plott.show()

# %%
y_train_pred = lin_reg.predict(X_train_sm)
res = (y_train - y_train_pred)
res
# Out:
# 10011   -206749.851615
# 6848    -144174.416731
# 16040   -199028.611637
# 11323   -192504.961637
# 8161     -63338.704087
#              ...
# 16304    -78658.248218
# 79       331523.918635
# 12119   -202097.421637
# 14147   -175596.401637
# 5640    -172911.004904
# Length: 12774, dtype: float64

# %%
fig = plott.figure()
sns.distplot(res, bins = 15)
plott.title('Error Terms', fontsize = 15)
plott.xlabel('y_train - y_train_pred', fontsize = 15)
plott.show()

# %%
plott.scatter(X_train,res)
plott.show()

# %%
X_test_sm = stats_mod.add_constant(X_test)
y_test_pred = lin_reg.predict(X_test_sm)
y_test_pred
# Out:
# 17091    2.067250e+05
# 9441     2.043463e+05
# 15443    2.043036e+05
# 10982    2.056537e+05
# 2671     3.211917e+07
#              ...
# 8531     2.719304e+05
# 13366    2.043036e+05
# 6157     2.228262e+05
# 13387    2.043036e+05
# 10693    2.043036e+05
# Length: 5475, dtype: float64

# %%
from sklearn.metrics import r2_score
r_squared = r2_score(y_test, y_test_pred)
r_squared
# Out:
# 0.7730577739758502

# %%
plott.scatter(X_test, y_test)
plott.plot(X_test, y_test_pred, 'r')
plott.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X, y = np.arange(10).reshape((5, 2)), range(5)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size = 0.7,
test_size = 0.3, random_state = 100)
X_train, X_test, y_train, y_test
# Out:
# (array([[6, 7],
#         [8, 9],
#         [0, 1]]),
#  array([[2, 3],
#         [4, 5]]),
#  [3, 4, 0],
#  [1, 2])

# %%
X_train.shape
X_train = X_train.values.reshape(-1,1)
X_test = X_test.values.reshape(-1,1)
print(X_train.shape)
print(X_test.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 2
#       1 X_train.shape
# ----> 2 X_train = X_train.values.reshape(-1,1)
#       3 X_test = X_test.values.reshape(-1,1)
#       4 print(X_train.shape)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Intercept :",lm.intercept_)
print('Slope :',lm.coef_)
# Out:
# Intercept : -0.24999999999999956
# Slope : [0.25 0.25]

# %%
y_train_pred = lm.predict(X_train)
y_test_pred = lm.predict(X_test)
print(r2_score(y_train,y_train_pred))
print(r2_score(y_test,y_test_pred))
# Out:
# 1.0
# 1.0
